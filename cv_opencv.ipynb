# %% [markdown]
# <a href="https://colab.research.google.com/github/ali7557/computer_vision/blob/main/cv_opencv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install opencv-python

# %%
import cv2

# %%
from google.colab.patches import cv2_imshow
image = cv2.imread("/content/download (1).jpg")


cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=164x148>

# %%
print("SHAPE:", image.shape)

# 463 => height
# 703 => width
# 3 => color channels (BGR) => Blue, Green, Red

print("HEIGHT:", image.shape[0])
print("WIDTH:", image.shape[1])
print("CHANNELS:", image.shape[2])
# Out:
# SHAPE: (148, 164, 3)
# HEIGHT: 148
# WIDTH: 164
# CHANNELS: 3

# %%
(b, g, r) = image[100, 50]

print("Blue:", b, "Green:", g, "Red:", r)
# Out:
# Blue: 21 Green: 41 Red: 59

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=164x148>

# %%
resized = cv2.resize(gray, (300, 300))
cv2_imshow(resized)
# Out:
# <PIL.Image.Image image mode=L size=300x300>

# %%
cropped = gray[100:300, 150:350]
cv2_imshow(cropped)
# Out:
# <PIL.Image.Image image mode=L size=14x48>

# %%
rotated = cv2.rotate(gray, cv2.ROTATE_90_COUNTERCLOCKWISE)
cv2_imshow(rotated)
# Out:
# <PIL.Image.Image image mode=L size=148x164>

# %%
cv2.imwrite("/content/cropped_cat.jpg", cropped)

cropped_cat = cv2.imread("/content/cropped_cat.jpg")
cv2_imshow(cropped_cat)
# Out:
# <PIL.Image.Image image mode=RGB size=14x48>

# %%
cropped_cat = cv2.imread("/content/cropped_cat.jpg")
if cropped_cat is not None:
    cv2_imshow(cropped_cat)
else:
    print("Error: Could not load image. Please ensure '/content/cropped_cat.jpg' exists and is accessible.")

# %%
# import cv2
import cv2
cap = cv2.VideoCapture(0)
face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

while True:
    success, frame = cap.read()  # True, False | Boolean
    if not success:
        break

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    face = face_cascade.detectMultiScale(gray, 1.5, 4)
    for (x, y, w, h) in face:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 4)

    cv2.imshow("Face Detection", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):  # 'q' tugmasi bosilganda ochishi
        break

cap.release()  # Ochiq qolgan oynalrni yopish uchun
cv2.destroyAllWindows()

print("Hello World!")


# url = "rtsp://192.168.1.164:8001/videp"

# cap = cv2.VideoCapture(url)
# while True:
#     success, frame = cap.read()  # True, False | Boolean
#     if not success:
#         break

#     # Rasmni kulrang rangga o'tkazish
#     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#     blurred = cv2.GaussianBlur(frame, (15, 15), 0)  # Rasmni blurlash
#     edgs = cv2.Canny(frame, 100, 200)  # Rasmning chekkalarini aniqlash
#     flip = cv2.flip(frame, 1)  # Rasmni gorizontal ravishda teskari qilish

#     # Oynani ochish va video oqimini ko'rsatish uchun
#     # cv2.imshow("Origina:", frame)
#     # cv2.imshow("Gray:", gray)
#     # cv2.imshow("Blurred:", blurred)
#     # cv2.imshow("Edges:", edgs)
#     cv2.imshow("Flipped:", flip)

#     if cv2.waitKey(1) & 0xFF == ord('q'):  # 'q' tugmasi bosilganda
#         break
# Out:
# Hello World!
